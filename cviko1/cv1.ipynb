# %%
import getpass
import requests

# %%
username=input("User:")
# Out:
# User:chovanecm@gmail.com

# %%
password=getpass.getpass()
# Out:
# ········

# %%
r = requests.get("https://api.github.com/user", auth=(username,password)
   ...: )

# %%
r
# Out:
# <Response [200]>

# %%
import pprint
pprint.pprint(r.json())
# Out:
# {'avatar_url': 'https://avatars.githubusercontent.com/u/3611258?v=3',
#  'bio': None,
#  'blog': None,
#  'collaborators': 0,
#  'company': None,
#  'created_at': '2013-02-16T14:06:14Z',
#  'disk_usage': 112,
#  'email': None,
#  'events_url': 'https://api.github.com/users/chovanecm/events{/privacy}',
#  'followers': 0,
#  'followers_url': 'https://api.github.com/users/chovanecm/followers',
#  'following': 0,
#  'following_url': 'https://api.github.com/users/chovanecm/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/chovanecm/gists{/gist_id}',
#  'gravatar_id': '',
#  'hireable': None,
#  'html_url': 'https://github.com/chovanecm',
#  'id': 3611258,
#  'location': None,
#  'login': 'chovanecm',
#  'name': None,
#  'organizations_url': 'https://api.github.com/users/chovanecm/orgs',
#  'owned_private_repos': 0,
#  'plan': {'collaborators': 0,
#           'name': 'personal',
#           'private_repos': 9999,
#           'space': 976562499},
#  'private_gists': 0,
# ...

# %%
pprint.pprint(dict(r.headers))
# Out:
# {'Access-Control-Allow-Origin': '*',
#  'Access-Control-Expose-Headers': 'ETag, Link, X-GitHub-OTP, '
#                                   'X-RateLimit-Limit, X-RateLimit-Remaining, '
#                                   'X-RateLimit-Reset, X-OAuth-Scopes, '
#                                   'X-Accepted-OAuth-Scopes, X-Poll-Interval',
#  'Cache-Control': 'private, max-age=60, s-maxage=60',
#  'Content-Encoding': 'gzip',
#  'Content-Security-Policy': "default-src 'none'",
#  'Content-Type': 'application/json; charset=utf-8',
#  'Date': 'Wed, 05 Oct 2016 09:31:49 GMT',
#  'ETag': 'W/"044f82b265581815c58e67d9370a98a6"',
#  'Last-Modified': 'Wed, 05 Oct 2016 09:03:42 GMT',
#  'Server': 'GitHub.com',
#  'Status': '200 OK',
#  'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload',
#  'Transfer-Encoding': 'chunked',
#  'Vary': 'Accept, Authorization, Cookie, X-GitHub-OTP, Accept-Encoding',
#  'X-Content-Type-Options': 'nosniff',
#  'X-Frame-Options': 'deny',
# ...

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.cookies.items()
# Out:
# []

# %%
list(r.cookies)
# Out:
# []

# %%
session = requests.Session()

# %%
r=session.get("http://httpbin.org/cookies/set/mipyt/best")

# %%
r.headers
# Out:
# {'Content-Length': '43', 'Server': 'nginx', 'Content-Type': 'application/json', 'Date': 'Wed, 05 Oct 2016 09:38:06 GMT', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Origin': '*', 'Connection': 'keep-alive'}

# %%
r.json()
# Out:
# {'cookies': {'mipyt': 'best'}}

# %%
r = session.get("http://httpbin.org/cookies")
r.json()
# Out:
# {'cookies': {'mipyt': 'best'}}

# %%
session.headers.update({"x-test": "true"})
r = session.get("http://httpbin.org/headers", headers={"x-test-2": "jo"})
r.json()
# Out:
# {'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Cookie': 'mipyt=best',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.11.1',
#   'X-Test': 'true',
#   'X-Test-2': 'jo'}}

# %%
#Twitter
r = session.get("https://api.twitter.com/1.1/search/tweets.json")
r.raise_for_status()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-24-2635fdc3dfc5> in <module>()
#       1 #Twitter
#       2 r = session.get("https://api.twitter.com/1.1/search/tweets.json")
# ----> 3 r.raise_for_status()
#
# /home/users/c/chovamar/mi-pyt/env/lib/python3.5/site-packages/requests/models.py in raise_for_status(self)
#     860
#     861         if http_error_msg:
# --> 862             raise HTTPError(http_error_msg, response=self)
#     863
#     864     def close(self):
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.twitter.com/1.1/search/tweets.json

# %%
r.json()
# Out:
# {'errors': [{'code': 215, 'message': 'Bad Authentication data.'}]}

# %%
api_key = getpass.getpass()
# Out:
# ········

# %%
api_secret = getpass.getpass()
# Out:
# ········

# %% [markdown]
# **This actually later included form custom defined twitter.py file**
# import base64
# secret = '{}:{}'.format(api_key, api_secret)
# secret64 = base64.b64encode(secret.encode('ascii')).decode('ascii')
# headers = {
#      'Authorization': 'Basic {}'.format(secret64),
#      'Host': 'api.twitter.com',
#  }
# r = session.post('https://api.twitter.com/oauth2/token',
#                   headers=headers,
#                   data={'grant_type': 'client_credentials'})
#
# bearer_token = r.json()['access_token']
# r.json()

# %% [markdown]
# **This actually later included form custom defined twitter.py file**
# def bearer_auth(req):
#     req.headers['Authorization'] = 'Bearer ' + bearer_token
#     return req
#
# session.auth = bearer_auth

# %%
import twitter #From local twitter.py

# %%
session = twitter.twitter_session(api_key, api_secret)

# %%
session.head
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-6ca2587783a8> in <module>()
# ----> 1 session.auth()
#
# TypeError: bearer_auth() missing 1 required positional argument: 'req'

# %%
r = session.get("https://api.twitter.com/1.1/search/tweets.json", params={"q": "#python"})

# %%
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'search_metadata': {'completed_in': 0.028,
#   'count': 15,
#   'max_id': 783609997171261440,
#   'max_id_str': '783609997171261440',
#   'next_results': '?max_id=783607062727057407&q=%23python&include_entities=1',
#   'query': '%23python',
#   'refresh_url': '?since_id=783609997171261440&q=%23python&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Oct 05 10:09:16 +0000 2016',
#    'entities': {'hashtags': [{'indices': [0, 11], 'text': 'JavaScript'},
#      {'indices': [13, 20], 'text': 'Python'}],
#     'media': [{'display_url': 'pic.twitter.com/to0WmT6p0Q',
#       'expanded_url': 'https://twitter.com/samm_emmanuel/status/783609987801223168/photo/1',
#       'id': 783609985838280705,
#       'id_str': '783609985838280705',
#       'indices': [114, 137],
#       'media_url': 'http://pbs.twimg.com/media/Ct_xIWBW8AEN1k1.jpg',
# ...
